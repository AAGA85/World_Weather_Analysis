# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 784

# %%
# Import the requests library.
import requests

# Import the API key.
from config1 import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=63c353b3e4da08f3cd53a5d782d0014a

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_descrip = city_weather["weather"][0]["description"]
      
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_descrip})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | alofi
# Processing Record 3 of Set 1 | yellowknife
# Processing Record 4 of Set 1 | boundiali
# Processing Record 5 of Set 1 | challapata
# Processing Record 6 of Set 1 | kolyshley
# Processing Record 7 of Set 1 | vaini
# Processing Record 8 of Set 1 | kawalu
# Processing Record 9 of Set 1 | bengkulu
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | tiksi
# Processing Record 12 of Set 1 | cape town
# Processing Record 13 of Set 1 | almenevo
# City not found. Skipping...
# Processing Record 14 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 15 of Set 1 | banda aceh
# Processing Record 16 of Set 1 | kabare
# Processing Record 17 of Set 1 | faya
# Processing Record 18 of Set 1 | mataura
# Processing Record 19 of Set 1 | mogadishu
# Processing Record 20 of Set 1 | lebu
# Processing Record 21 of Set 1 | havre-saint-pierre
# Processing Record 22 of Set 1 | kodiak
# Processing Record 23 of Set 1 | torbay
# Processing Record 24 of Set 1 | dukat
# Processing Record 25 of Set 1 | cherskiy
# Processing Record 26 of Set 1 | ushuaia
# Processing Record 27 of Set 1 | coahuayana
# Processing Record 28 of Set 1 | porto walter
# Processing Record 29 of Set 1 | gannan
# Processing Record 30 of Set 1 | bluff
# Processing Record 31 of Set 1 | jiddah
# City not found. Skipping...
# Processing Record 32 of Set 1 | hermanus
# Processing Record 33 of Set 1 | cidreira
# Processing Record 34 of Set 1 | avarua
# Processing Record 35 of Set 1 | kapaa
# Processing Record 36 of Set 1 | dongsheng
# Processing Record 37 of Set 1 | ciudad bolivar
# Processing Record 38 of Set 1 | okhotsk
# Processing Record 39 of Set 1 | lamu
# Processing Record 40 of Set 1 | kavieng
# Processing Record 41 of Set 1 | bredasdorp
# Processing Record 42 of Set 1 | talnakh
# Processing Record 43 of Set 1 | muros
# Processing Record 44 of Set 1 | sibolga
# Processing Record 45 of Set 1 | mundo nuevo
# Processing Record 46 of Set 1 | phan thiet
# Processing Record 47 of Set 1 | ponta do sol
# Processing Record 48 of Set 1 | tasiilaq
# Processing Record 49 of Set 1 | marawi
# Processing Record 50 of Set 1 | sept-iles
# Processing Record 1 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 2 of Set 2 | carolina
# Processing Record 3 of Set 2 | merke
# Processing Record 4 of Set 2 | butaritari
# Processing Record 5 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 2 | severo-kurilsk
# Processing Record 8 of Set 2 | moose factory
# Processing Record 9 of Set 2 | dobrun
# Processing Record 10 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 11 of Set 2 | ahipara
# Processing Record 12 of Set 2 | pevek
# Processing Record 13 of Set 2 | bethel
# Processing Record 14 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 15 of Set 2 | dikson
# Processing Record 16 of Set 2 | lorengau
# Processing Record 17 of Set 2 | tuktoyaktuk
# Processing Record 18 of Set 2 | hofn
# Processing Record 19 of Set 2 | benguela
# Processing Record 20 of Set 2 | nizhniy ingash
# Processing Record 21 of Set 2 | araouane
# Processing Record 22 of Set 2 | lata
# Processing Record 23 of Set 2 | sitka
# Processing Record 24 of Set 2 | agirish
# Processing Record 25 of Set 2 | hilo
# Processing Record 26 of Set 2 | clyde river
# Processing Record 27 of Set 2 | sonneberg
# Processing Record 28 of Set 2 | kenora
# Processing Record 29 of Set 2 | springbok
# Processing Record 30 of Set 2 | nara
# Processing Record 31 of Set 2 | esperance
# Processing Record 32 of Set 2 | davidson
# Processing Record 33 of Set 2 | utiroa
# City not found. Skipping...
# Processing Record 34 of Set 2 | saskylakh
# Processing Record 35 of Set 2 | georgetown
# Processing Record 36 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 37 of Set 2 | carnarvon
# Processing Record 38 of Set 2 | saint george
# Processing Record 39 of Set 2 | new norfolk
# Processing Record 40 of Set 2 | amazar
# Processing Record 41 of Set 2 | kavaratti
# Processing Record 42 of Set 2 | aripuana
# Processing Record 43 of Set 2 | newtownards
# Processing Record 44 of Set 2 | plouzane
# Processing Record 45 of Set 2 | buenos aires
# Processing Record 46 of Set 2 | bushehr
# Processing Record 47 of Set 2 | bambous virieux
# Processing Record 48 of Set 2 | saint-philippe
# Processing Record 49 of Set 2 | gravdal
# Processing Record 50 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 3 | saint-joseph
# Processing Record 2 of Set 3 | soyo
# Processing Record 3 of Set 3 | effium
# Processing Record 4 of Set 3 | hithadhoo
# Processing Record 5 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 6 of Set 3 | burnie
# Processing Record 7 of Set 3 | chute-aux-outardes
# Processing Record 8 of Set 3 | albany
# Processing Record 9 of Set 3 | hobart
# Processing Record 10 of Set 3 | pimentel
# Processing Record 11 of Set 3 | arraial do cabo
# Processing Record 12 of Set 3 | moss point
# Processing Record 13 of Set 3 | port alfred
# Processing Record 14 of Set 3 | galdar
# Processing Record 15 of Set 3 | acapulco
# Processing Record 16 of Set 3 | roald
# Processing Record 17 of Set 3 | khatanga
# Processing Record 18 of Set 3 | ribeira grande
# Processing Record 19 of Set 3 | belaya gora
# Processing Record 20 of Set 3 | mapimi
# Processing Record 21 of Set 3 | hualmay
# Processing Record 22 of Set 3 | den chai
# Processing Record 23 of Set 3 | jamestown
# Processing Record 24 of Set 3 | vanimo
# Processing Record 25 of Set 3 | leshukonskoye
# Processing Record 26 of Set 3 | tawang
# Processing Record 27 of Set 3 | kaitangata
# Processing Record 28 of Set 3 | lynchburg
# Processing Record 29 of Set 3 | port elizabeth
# Processing Record 30 of Set 3 | sihora
# Processing Record 31 of Set 3 | castro
# Processing Record 32 of Set 3 | terrak
# Processing Record 33 of Set 3 | chokurdakh
# Processing Record 34 of Set 3 | santa cruz
# Processing Record 35 of Set 3 | beringovskiy
# Processing Record 36 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 37 of Set 3 | tartagal
# Processing Record 38 of Set 3 | morshansk
# Processing Record 39 of Set 3 | upernavik
# Processing Record 40 of Set 3 | iqaluit
# Processing Record 41 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 42 of Set 3 | aklavik
# Processing Record 43 of Set 3 | broken hill
# Processing Record 44 of Set 3 | ruteng
# Processing Record 45 of Set 3 | puerto ayora
# Processing Record 46 of Set 3 | ugoofaaru
# Processing Record 47 of Set 3 | zyryanka
# Processing Record 48 of Set 3 | desaguadero
# Processing Record 49 of Set 3 | sur
# Processing Record 50 of Set 3 | yerbogachen
# Processing Record 1 of Set 4 | chuy
# Processing Record 2 of Set 4 | champerico
# Processing Record 3 of Set 4 | qaanaaq
# Processing Record 4 of Set 4 | aykhal
# Processing Record 5 of Set 4 | skalistyy
# City not found. Skipping...
# Processing Record 6 of Set 4 | lagoa
# Processing Record 7 of Set 4 | polovinnoye
# Processing Record 8 of Set 4 | atuona
# Processing Record 9 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 10 of Set 4 | moroto
# Processing Record 11 of Set 4 | fairbanks
# Processing Record 12 of Set 4 | nivala
# Processing Record 13 of Set 4 | tuxpan
# Processing Record 14 of Set 4 | at-bashi
# Processing Record 15 of Set 4 | wanning
# Processing Record 16 of Set 4 | lumberton
# Processing Record 17 of Set 4 | svetlyy
# Processing Record 18 of Set 4 | fare
# Processing Record 19 of Set 4 | itaueira
# Processing Record 20 of Set 4 | mahebourg
# Processing Record 21 of Set 4 | phan rang
# City not found. Skipping...
# Processing Record 22 of Set 4 | belmonte
# Processing Record 23 of Set 4 | omsukchan
# Processing Record 24 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 4 | micheweni
# Processing Record 26 of Set 4 | airai
# Processing Record 27 of Set 4 | riyadh
# Processing Record 28 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 4 | barrow
# Processing Record 30 of Set 4 | mishan
# Processing Record 31 of Set 4 | nabire
# Processing Record 32 of Set 4 | uwajima
# Processing Record 33 of Set 4 | nemuro
# Processing Record 34 of Set 4 | beidao
# Processing Record 35 of Set 4 | elliot
# Processing Record 36 of Set 4 | karamay
# City not found. Skipping...
# Processing Record 37 of Set 4 | bubaque
# Processing Record 38 of Set 4 | punta arenas
# Processing Record 39 of Set 4 | salta
# Processing Record 40 of Set 4 | sarkand
# Processing Record 41 of Set 4 | krasnoselkup
# Processing Record 42 of Set 4 | batagay
# Processing Record 43 of Set 4 | banikoara
# Processing Record 44 of Set 4 | yarmouth
# Processing Record 45 of Set 4 | leighton buzzard
# Processing Record 46 of Set 4 | saldanha
# Processing Record 47 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 48 of Set 4 | darhan
# Processing Record 49 of Set 4 | bundu
# Processing Record 50 of Set 4 | thompson
# Processing Record 1 of Set 5 | kruisfontein
# Processing Record 2 of Set 5 | mecca
# Processing Record 3 of Set 5 | ulaanbaatar
# Processing Record 4 of Set 5 | sedelnikovo
# City not found. Skipping...
# Processing Record 5 of Set 5 | leningradskiy
# Processing Record 6 of Set 5 | amarante do maranhao
# Processing Record 7 of Set 5 | hambantota
# Processing Record 8 of Set 5 | port hedland
# Processing Record 9 of Set 5 | saint-louis
# Processing Record 10 of Set 5 | teseney
# Processing Record 11 of Set 5 | cockburn town
# Processing Record 12 of Set 5 | samsun
# Processing Record 13 of Set 5 | kirando
# Processing Record 14 of Set 5 | rameswaram
# Processing Record 15 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 16 of Set 5 | arahal
# Processing Record 17 of Set 5 | lamar
# Processing Record 18 of Set 5 | norman wells
# Processing Record 19 of Set 5 | gao
# Processing Record 20 of Set 5 | bairiki
# Processing Record 21 of Set 5 | uchiza
# Processing Record 22 of Set 5 | inderborskiy
# City not found. Skipping...
# Processing Record 23 of Set 5 | solnechnyy
# Processing Record 24 of Set 5 | swan hill
# Processing Record 25 of Set 5 | richards bay
# Processing Record 26 of Set 5 | jaisinghnagar
# Processing Record 27 of Set 5 | guerrero negro
# Processing Record 28 of Set 5 | libertador general san martin
# Processing Record 29 of Set 5 | namibe
# Processing Record 30 of Set 5 | alta floresta
# Processing Record 31 of Set 5 | klaksvik
# Processing Record 32 of Set 5 | east london
# Processing Record 33 of Set 5 | kutum
# Processing Record 34 of Set 5 | aljezur
# Processing Record 35 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 36 of Set 5 | taltal
# Processing Record 37 of Set 5 | qaqortoq
# Processing Record 38 of Set 5 | calvinia
# Processing Record 39 of Set 5 | asau
# Processing Record 40 of Set 5 | martapura
# Processing Record 41 of Set 5 | kidal
# Processing Record 42 of Set 5 | kencong
# Processing Record 43 of Set 5 | lazaro cardenas
# Processing Record 44 of Set 5 | mahajanga
# Processing Record 45 of Set 5 | gazanjyk
# Processing Record 46 of Set 5 | mastic beach
# Processing Record 47 of Set 5 | castlegar
# Processing Record 48 of Set 5 | bathsheba
# Processing Record 49 of Set 5 | grand-santi
# Processing Record 50 of Set 5 | eyl
# Processing Record 1 of Set 6 | ransang
# Processing Record 2 of Set 6 | lodingen
# Processing Record 3 of Set 6 | ginda
# Processing Record 4 of Set 6 | gimli
# Processing Record 5 of Set 6 | maghama
# City not found. Skipping...
# Processing Record 6 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 7 of Set 6 | mar del plata
# Processing Record 8 of Set 6 | gat
# Processing Record 9 of Set 6 | dingle
# Processing Record 10 of Set 6 | cairns
# Processing Record 11 of Set 6 | antonovo
# Processing Record 12 of Set 6 | raduzhnyy
# Processing Record 13 of Set 6 | robertsport
# Processing Record 14 of Set 6 | te anau
# Processing Record 15 of Set 6 | rio grande
# Processing Record 16 of Set 6 | tuatapere
# Processing Record 17 of Set 6 | srednekolymsk
# Processing Record 18 of Set 6 | salalah
# Processing Record 19 of Set 6 | ostrovnoy
# Processing Record 20 of Set 6 | koslan
# Processing Record 21 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 6 | muhoroni
# Processing Record 23 of Set 6 | blackwater
# Processing Record 24 of Set 6 | port lincoln
# Processing Record 25 of Set 6 | nikolskoye
# Processing Record 26 of Set 6 | constantine
# Processing Record 27 of Set 6 | xacmaz
# Processing Record 28 of Set 6 | nantucket
# Processing Record 29 of Set 6 | ancud
# Processing Record 30 of Set 6 | yulara
# Processing Record 31 of Set 6 | haines junction
# Processing Record 32 of Set 6 | fort nelson
# Processing Record 33 of Set 6 | dalby
# Processing Record 34 of Set 6 | hovd
# Processing Record 35 of Set 6 | baoro
# Processing Record 36 of Set 6 | provideniya
# Processing Record 37 of Set 6 | payo
# Processing Record 38 of Set 6 | smithers
# Processing Record 39 of Set 6 | victoria
# Processing Record 40 of Set 6 | nouadhibou
# Processing Record 41 of Set 6 | meulaboh
# Processing Record 42 of Set 6 | ornskoldsvik
# Processing Record 43 of Set 6 | illapel
# Processing Record 44 of Set 6 | vostok
# Processing Record 45 of Set 6 | adrar
# Processing Record 46 of Set 6 | ketchikan
# Processing Record 47 of Set 6 | hay river
# Processing Record 48 of Set 6 | henties bay
# Processing Record 49 of Set 6 | kudahuvadhoo
# Processing Record 50 of Set 6 | nadym
# Processing Record 1 of Set 7 | atlantic beach
# Processing Record 2 of Set 7 | opuwo
# Processing Record 3 of Set 7 | loa janan
# Processing Record 4 of Set 7 | glace bay
# Processing Record 5 of Set 7 | kwinana
# Processing Record 6 of Set 7 | port townsend
# Processing Record 7 of Set 7 | falealupo
# City not found. Skipping...
# Processing Record 8 of Set 7 | katsuura
# Processing Record 9 of Set 7 | souillac
# Processing Record 10 of Set 7 | mahibadhoo
# Processing Record 11 of Set 7 | porangatu
# Processing Record 12 of Set 7 | centralia
# Processing Record 13 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 14 of Set 7 | ozamiz
# Processing Record 15 of Set 7 | tlaxiaco
# City not found. Skipping...
# Processing Record 16 of Set 7 | ballina
# Processing Record 17 of Set 7 | dryden
# Processing Record 18 of Set 7 | karratha
# Processing Record 19 of Set 7 | nagato
# Processing Record 20 of Set 7 | mancio lima
# Processing Record 21 of Set 7 | mulchen
# Processing Record 22 of Set 7 | kemalpasa
# Processing Record 23 of Set 7 | codrington
# Processing Record 24 of Set 7 | husavik
# Processing Record 25 of Set 7 | mandera
# Processing Record 26 of Set 7 | huilong
# Processing Record 27 of Set 7 | sistranda
# Processing Record 28 of Set 7 | bantry
# Processing Record 29 of Set 7 | la ronge
# Processing Record 30 of Set 7 | saint-pierre
# Processing Record 31 of Set 7 | viedma
# Processing Record 32 of Set 7 | anadyr
# Processing Record 33 of Set 7 | aktash
# Processing Record 34 of Set 7 | rocha
# Processing Record 35 of Set 7 | alexandria
# Processing Record 36 of Set 7 | hamilton
# Processing Record 37 of Set 7 | ushibuka
# Processing Record 38 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 39 of Set 7 | tongchuan
# Processing Record 40 of Set 7 | prince rupert
# Processing Record 41 of Set 7 | shihezi
# Processing Record 42 of Set 7 | kieta
# Processing Record 43 of Set 7 | boa vista
# Processing Record 44 of Set 7 | asyut
# Processing Record 45 of Set 7 | manaus
# Processing Record 46 of Set 7 | rostaq
# City not found. Skipping...
# Processing Record 47 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 48 of Set 7 | gorontalo
# Processing Record 49 of Set 7 | upata
# Processing Record 50 of Set 7 | buariki
# City not found. Skipping...
# Processing Record 1 of Set 8 | sobolevo
# Processing Record 2 of Set 8 | caravelas
# Processing Record 3 of Set 8 | ahualulco
# Processing Record 4 of Set 8 | wajima
# Processing Record 5 of Set 8 | tomatlan
# Processing Record 6 of Set 8 | miandrivazo
# Processing Record 7 of Set 8 | kommunisticheskiy
# Processing Record 8 of Set 8 | margate
# Processing Record 9 of Set 8 | sao felix do xingu
# Processing Record 10 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 11 of Set 8 | keetmanshoop
# Processing Record 12 of Set 8 | dicabisagan
# Processing Record 13 of Set 8 | beloye
# Processing Record 14 of Set 8 | teya
# Processing Record 15 of Set 8 | geraldton
# Processing Record 16 of Set 8 | bonavista
# Processing Record 17 of Set 8 | diffa
# Processing Record 18 of Set 8 | sinnamary
# Processing Record 19 of Set 8 | itoman
# Processing Record 20 of Set 8 | comodoro rivadavia
# Processing Record 21 of Set 8 | guiren
# Processing Record 22 of Set 8 | mandan
# Processing Record 23 of Set 8 | ndjole
# Processing Record 24 of Set 8 | kati
# Processing Record 25 of Set 8 | san cristobal
# Processing Record 26 of Set 8 | mosquera
# Processing Record 27 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 8 | joao camara
# Processing Record 29 of Set 8 | tokmak
# Processing Record 30 of Set 8 | sao filipe
# Processing Record 31 of Set 8 | basoko
# Processing Record 32 of Set 8 | bani
# Processing Record 33 of Set 8 | camacupa
# Processing Record 34 of Set 8 | moron
# Processing Record 35 of Set 8 | deputatskiy
# Processing Record 36 of Set 8 | clearlake
# Processing Record 37 of Set 8 | mabasa
# Processing Record 38 of Set 8 | mataram
# Processing Record 39 of Set 8 | kiama
# Processing Record 40 of Set 8 | brae
# Processing Record 41 of Set 8 | lagos
# Processing Record 42 of Set 8 | faanui
# Processing Record 43 of Set 8 | armizonskoye
# Processing Record 44 of Set 8 | mandalgovi
# Processing Record 45 of Set 8 | asosa
# Processing Record 46 of Set 8 | valer
# Processing Record 47 of Set 8 | bud
# Processing Record 48 of Set 8 | kenai
# Processing Record 49 of Set 8 | north bend
# Processing Record 50 of Set 8 | maniitsoq
# Processing Record 1 of Set 9 | huarmey
# Processing Record 2 of Set 9 | kashary
# Processing Record 3 of Set 9 | gold coast
# Processing Record 4 of Set 9 | teterow
# Processing Record 5 of Set 9 | sataua
# City not found. Skipping...
# Processing Record 6 of Set 9 | shalya
# Processing Record 7 of Set 9 | constitucion
# Processing Record 8 of Set 9 | gallup
# Processing Record 9 of Set 9 | anisoc
# Processing Record 10 of Set 9 | naze
# Processing Record 11 of Set 9 | little current
# Processing Record 12 of Set 9 | beyneu
# Processing Record 13 of Set 9 | guanica
# Processing Record 14 of Set 9 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 15 of Set 9 | tungkang
# City not found. Skipping...
# Processing Record 16 of Set 9 | mnogovershinnyy
# Processing Record 17 of Set 9 | sioux lookout
# Processing Record 18 of Set 9 | kourou
# Processing Record 19 of Set 9 | cabo san lucas
# Processing Record 20 of Set 9 | grand island
# Processing Record 21 of Set 9 | atasu
# Processing Record 22 of Set 9 | praxedis guerrero
# Processing Record 23 of Set 9 | longyearbyen
# Processing Record 24 of Set 9 | nelson bay
# Processing Record 25 of Set 9 | lompoc
# Processing Record 26 of Set 9 | mineros
# Processing Record 27 of Set 9 | san andres
# Processing Record 28 of Set 9 | tabas
# Processing Record 29 of Set 9 | ardakan
# Processing Record 30 of Set 9 | ayan
# Processing Record 31 of Set 9 | nizhniy odes
# Processing Record 32 of Set 9 | mascote
# Processing Record 33 of Set 9 | kytlym
# City not found. Skipping...
# Processing Record 34 of Set 9 | yakeshi
# Processing Record 35 of Set 9 | skjervoy
# Processing Record 36 of Set 9 | puerto escondido
# Processing Record 37 of Set 9 | san juan
# Processing Record 38 of Set 9 | matina
# Processing Record 39 of Set 9 | vila velha
# Processing Record 40 of Set 9 | fuerte olimpo
# Processing Record 41 of Set 9 | charlestown
# Processing Record 42 of Set 9 | dillon
# Processing Record 43 of Set 9 | lawrenceburg
# Processing Record 44 of Set 9 | ventspils
# Processing Record 45 of Set 9 | komsomolskiy
# Processing Record 46 of Set 9 | hami
# Processing Record 47 of Set 9 | haibowan
# City not found. Skipping...
# Processing Record 48 of Set 9 | zhigansk
# Processing Record 49 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 50 of Set 9 | colombo
# Processing Record 1 of Set 10 | meadow lake
# Processing Record 2 of Set 10 | yanam
# Processing Record 3 of Set 10 | arlit
# Processing Record 4 of Set 10 | okandja
# City not found. Skipping...
# Processing Record 5 of Set 10 | prieska
# Processing Record 6 of Set 10 | san julian
# Processing Record 7 of Set 10 | riviere-au-renard
# Processing Record 8 of Set 10 | miraflores
# Processing Record 9 of Set 10 | wuning
# Processing Record 10 of Set 10 | havelock
# Processing Record 11 of Set 10 | jiayuguan
# Processing Record 12 of Set 10 | qasigiannguit
# Processing Record 13 of Set 10 | santa maria
# Processing Record 14 of Set 10 | kupang
# Processing Record 15 of Set 10 | zubtsov
# Processing Record 16 of Set 10 | zhuhai
# Processing Record 17 of Set 10 | piranhas
# Processing Record 18 of Set 10 | half moon bay
# Processing Record 19 of Set 10 | djibo
# Processing Record 20 of Set 10 | svetlaya
# Processing Record 21 of Set 10 | vestmannaeyjar
# Processing Record 22 of Set 10 | mehamn
# Processing Record 23 of Set 10 | escanaba
# Processing Record 24 of Set 10 | san policarpo
# Processing Record 25 of Set 10 | rameshki
# Processing Record 26 of Set 10 | malanville
# Processing Record 27 of Set 10 | khovu-aksy
# Processing Record 28 of Set 10 | tawkar
# City not found. Skipping...
# Processing Record 29 of Set 10 | byron bay
# Processing Record 30 of Set 10 | nchelenge
# Processing Record 31 of Set 10 | penzance
# Processing Record 32 of Set 10 | touba
# Processing Record 33 of Set 10 | buala
# Processing Record 34 of Set 10 | dandong
# Processing Record 35 of Set 10 | thinadhoo
# Processing Record 36 of Set 10 | bafq
# Processing Record 37 of Set 10 | mys shmidta
# City not found. Skipping...
# Processing Record 38 of Set 10 | ocampo
# Processing Record 39 of Set 10 | port hardy
# Processing Record 40 of Set 10 | lerwick
# Processing Record 41 of Set 10 | moussoro
# Processing Record 42 of Set 10 | cockburn harbour
# City not found. Skipping...
# Processing Record 43 of Set 10 | redmond
# Processing Record 44 of Set 10 | laramie
# Processing Record 45 of Set 10 | ayagoz
# Processing Record 46 of Set 10 | ranong
# Processing Record 47 of Set 10 | kot addu
# Processing Record 48 of Set 10 | pangnirtung
# Processing Record 49 of Set 10 | kahului
# Processing Record 50 of Set 10 | rockland
# Processing Record 1 of Set 11 | turbat
# Processing Record 2 of Set 11 | cartagena
# Processing Record 3 of Set 11 | pisco
# Processing Record 4 of Set 11 | fortuna
# Processing Record 5 of Set 11 | el alto
# Processing Record 6 of Set 11 | port-cartier
# Processing Record 7 of Set 11 | mantua
# Processing Record 8 of Set 11 | narsaq
# Processing Record 9 of Set 11 | ust-nera
# Processing Record 10 of Set 11 | hasaki
# Processing Record 11 of Set 11 | portland
# Processing Record 12 of Set 11 | oussouye
# Processing Record 13 of Set 11 | bandarbeyla
# Processing Record 14 of Set 11 | buhe
# Processing Record 15 of Set 11 | mezen
# Processing Record 16 of Set 11 | tepalcatepec
# Processing Record 17 of Set 11 | kushiro
# Processing Record 18 of Set 11 | xuddur
# Processing Record 19 of Set 11 | kirakira
# Processing Record 20 of Set 11 | heihe
# Processing Record 21 of Set 11 | rivera
# Processing Record 22 of Set 11 | sosnovo-ozerskoye
# Processing Record 23 of Set 11 | mingaora
# Processing Record 24 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 11 | george
# Processing Record 26 of Set 11 | tateyama
# Processing Record 27 of Set 11 | nizhnevartovsk
# Processing Record 28 of Set 11 | okakarara
# Processing Record 29 of Set 11 | pangai
# Processing Record 30 of Set 11 | bull savanna
# Processing Record 31 of Set 11 | sharjah
# Processing Record 32 of Set 11 | tura
# Processing Record 33 of Set 11 | seoul
# Processing Record 34 of Set 11 | port blair
# Processing Record 35 of Set 11 | kattivakkam
# Processing Record 36 of Set 11 | vao
# Processing Record 37 of Set 11 | kalianget
# Processing Record 38 of Set 11 | baltay
# Processing Record 39 of Set 11 | saint-francois
# Processing Record 40 of Set 11 | cayenne
# Processing Record 41 of Set 11 | san quintin
# Processing Record 42 of Set 11 | ginir
# Processing Record 43 of Set 11 | trinidad
# Processing Record 44 of Set 11 | norrkoping
# Processing Record 45 of Set 11 | coquimbo
# Processing Record 46 of Set 11 | nenagh
# Processing Record 47 of Set 11 | parana
# Processing Record 48 of Set 11 | milan
# Processing Record 49 of Set 11 | loralai
# Processing Record 50 of Set 11 | wajir
# Processing Record 1 of Set 12 | alvdal
# Processing Record 2 of Set 12 | damavand
# Processing Record 3 of Set 12 | yeppoon
# Processing Record 4 of Set 12 | mount isa
# Processing Record 5 of Set 12 | trairi
# Processing Record 6 of Set 12 | el tigre
# Processing Record 7 of Set 12 | naryan-mar
# Processing Record 8 of Set 12 | atar
# Processing Record 9 of Set 12 | manokwari
# Processing Record 10 of Set 12 | saint anthony
# Processing Record 11 of Set 12 | surt
# Processing Record 12 of Set 12 | loreto
# Processing Record 13 of Set 12 | sivas
# Processing Record 14 of Set 12 | ceres
# Processing Record 15 of Set 12 | sampit
# Processing Record 16 of Set 12 | college
# Processing Record 17 of Set 12 | port augusta
# Processing Record 18 of Set 12 | wisconsin rapids
# Processing Record 19 of Set 12 | waipawa
# Processing Record 20 of Set 12 | ulagan
# Processing Record 21 of Set 12 | itacoatiara
# Processing Record 22 of Set 12 | mizdah
# Processing Record 23 of Set 12 | great falls
# Processing Record 24 of Set 12 | brandfort
# Processing Record 25 of Set 12 | wajid
# Processing Record 26 of Set 12 | bongandanga
# Processing Record 27 of Set 12 | ludvika
# Processing Record 28 of Set 12 | takoradi
# Processing Record 29 of Set 12 | sao jose da coroa grande
# Processing Record 30 of Set 12 | kano
# Processing Record 31 of Set 12 | goya
# Processing Record 32 of Set 12 | verkhnevilyuysk
# Processing Record 33 of Set 12 | necochea
# Processing Record 34 of Set 12 | aswan
# Processing Record 35 of Set 12 | maslovka
# Processing Record 36 of Set 12 | agadir
# Processing Record 37 of Set 12 | murgab
# Processing Record 38 of Set 12 | alice springs
# Processing Record 39 of Set 12 | afsin
# Processing Record 40 of Set 12 | beloha
# Processing Record 41 of Set 12 | manicore
# Processing Record 42 of Set 12 | usinsk
# Processing Record 43 of Set 12 | linxia
# Processing Record 44 of Set 12 | padang
# Processing Record 45 of Set 12 | zermatt
# Processing Record 46 of Set 12 | sisimiut
# Processing Record 47 of Set 12 | reconquista
# Processing Record 48 of Set 12 | piopio
# Processing Record 49 of Set 12 | skoghall
# Processing Record 50 of Set 12 | amalapuram
# Processing Record 1 of Set 13 | palmer
# Processing Record 2 of Set 13 | la grande
# Processing Record 3 of Set 13 | poum
# Processing Record 4 of Set 13 | nanortalik
# Processing Record 5 of Set 13 | rosenberg
# Processing Record 6 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 7 of Set 13 | lipari
# Processing Record 8 of Set 13 | tarauaca
# Processing Record 9 of Set 13 | santa isabel do rio negro
# Processing Record 10 of Set 13 | tim
# Processing Record 11 of Set 13 | lanskroun
# Processing Record 12 of Set 13 | charters towers
# Processing Record 13 of Set 13 | anyang
# Processing Record 14 of Set 13 | umm lajj
# Processing Record 15 of Set 13 | iralaya
# Processing Record 16 of Set 13 | tonantins
# Processing Record 17 of Set 13 | sorland
# Processing Record 18 of Set 13 | praia
# Processing Record 19 of Set 13 | mana
# Processing Record 20 of Set 13 | villazon
# Processing Record 21 of Set 13 | kodinar
# Processing Record 22 of Set 13 | vilhena
# Processing Record 23 of Set 13 | malinyi
# Processing Record 24 of Set 13 | san luis
# Processing Record 25 of Set 13 | kizilskoye
# Processing Record 26 of Set 13 | fairlie
# Processing Record 27 of Set 13 | isangel
# Processing Record 28 of Set 13 | stromness
# Processing Record 29 of Set 13 | henderson
# Processing Record 30 of Set 13 | zachagansk
# City not found. Skipping...
# Processing Record 31 of Set 13 | shelekhov
# Processing Record 32 of Set 13 | mitu
# Processing Record 33 of Set 13 | kadykchan
# City not found. Skipping...
# Processing Record 34 of Set 13 | luderitz
# Processing Record 35 of Set 13 | zhangzhou
# Processing Record 36 of Set 13 | zverinogolovskoye
# Processing Record 37 of Set 13 | briceni
# Processing Record 38 of Set 13 | ust-tsilma
# Processing Record 39 of Set 13 | tabango
# Processing Record 40 of Set 13 | elizabeth city
# Processing Record 41 of Set 13 | camacha
# Processing Record 42 of Set 13 | nynashamn
# Processing Record 43 of Set 13 | klyuchevskiy
# Processing Record 44 of Set 13 | shingu
# Processing Record 45 of Set 13 | paamiut
# Processing Record 46 of Set 13 | itarema
# Processing Record 47 of Set 13 | zaozerne
# Processing Record 48 of Set 13 | shieli
# Processing Record 49 of Set 13 | nome
# Processing Record 50 of Set 13 | baculin
# Processing Record 1 of Set 14 | nekhayevskiy
# Processing Record 2 of Set 14 | the pas
# Processing Record 3 of Set 14 | hvolsvollur
# Processing Record 4 of Set 14 | cabra
# Processing Record 5 of Set 14 | ayorou
# Processing Record 6 of Set 14 | pontianak
# Processing Record 7 of Set 14 | bridlington
# Processing Record 8 of Set 14 | urengoy
# Processing Record 9 of Set 14 | arawa
# Processing Record 10 of Set 14 | kailua
# Processing Record 11 of Set 14 | lekoni
# Processing Record 12 of Set 14 | lasa
# Processing Record 13 of Set 14 | misratah
# Processing Record 14 of Set 14 | alekseyevka
# Processing Record 15 of Set 14 | flin flon
# Processing Record 16 of Set 14 | naifaru
# Processing Record 17 of Set 14 | nyurba
# Processing Record 18 of Set 14 | bereda
# Processing Record 19 of Set 14 | chumikan
# Processing Record 20 of Set 14 | tczew
# Processing Record 21 of Set 14 | nova soure
# Processing Record 22 of Set 14 | ust-ishim
# Processing Record 23 of Set 14 | mao
# Processing Record 24 of Set 14 | severnyy
# Processing Record 25 of Set 14 | peniche
# Processing Record 26 of Set 14 | icod de los vinos
# Processing Record 27 of Set 14 | pauini
# Processing Record 28 of Set 14 | erzin
# Processing Record 29 of Set 14 | utica
# Processing Record 30 of Set 14 | zlotoryja
# Processing Record 31 of Set 14 | teacapan
# Processing Record 32 of Set 14 | mount gambier
# Processing Record 33 of Set 14 | abnub
# Processing Record 34 of Set 14 | teahupoo
# Processing Record 35 of Set 14 | kirensk
# Processing Record 36 of Set 14 | innisfail
# Processing Record 37 of Set 14 | igarka
# Processing Record 38 of Set 14 | borogontsy
# Processing Record 39 of Set 14 | copiapo
# Processing Record 40 of Set 14 | singarayakonda
# Processing Record 41 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 42 of Set 14 | camopi
# Processing Record 43 of Set 14 | coos bay
# Processing Record 44 of Set 14 | mazamet
# Processing Record 45 of Set 14 | ponta delgada
# Processing Record 46 of Set 14 | kushmurun
# Processing Record 47 of Set 14 | hwange
# Processing Record 48 of Set 14 | basco
# Processing Record 49 of Set 14 | elesbao veloso
# Processing Record 50 of Set 14 | mulege
# Processing Record 1 of Set 15 | labuhan
# Processing Record 2 of Set 15 | parral
# Processing Record 3 of Set 15 | palmares do sul
# Processing Record 4 of Set 15 | zabol
# Processing Record 5 of Set 15 | grande-riviere
# City not found. Skipping...
# Processing Record 6 of Set 15 | kaka
# Processing Record 7 of Set 15 | champaign
# Processing Record 8 of Set 15 | mahabad
# Processing Record 9 of Set 15 | watertown
# Processing Record 10 of Set 15 | plettenberg bay
# Processing Record 11 of Set 15 | chitral
# Processing Record 12 of Set 15 | tambacounda
# Processing Record 13 of Set 15 | egvekinot
# Processing Record 14 of Set 15 | pec
# Processing Record 15 of Set 15 | nangomba
# Processing Record 16 of Set 15 | santiago del estero
# Processing Record 17 of Set 15 | saint-georges
# Processing Record 18 of Set 15 | ruatoria
# City not found. Skipping...
# Processing Record 19 of Set 15 | yellandu
# Processing Record 20 of Set 15 | puerto quijarro
# Processing Record 21 of Set 15 | camaqua
# Processing Record 22 of Set 15 | moberly
# Processing Record 23 of Set 15 | belyy yar
# Processing Record 24 of Set 15 | khuzhir
# Processing Record 25 of Set 15 | ixtapa
# Processing Record 26 of Set 15 | nanga eboko
# Processing Record 27 of Set 15 | bondo
# Processing Record 28 of Set 15 | corinto
# Processing Record 29 of Set 15 | phangnga
# Processing Record 30 of Set 15 | porto torres
# Processing Record 31 of Set 15 | hunza
# City not found. Skipping...
# Processing Record 32 of Set 15 | monze
# Processing Record 33 of Set 15 | catuday
# Processing Record 34 of Set 15 | fukue
# Processing Record 35 of Set 15 | nairobi
# Processing Record 36 of Set 15 | wagar
# Processing Record 37 of Set 15 | chama
# Processing Record 38 of Set 15 | tarakan
# Processing Record 39 of Set 15 | barth
# Processing Record 40 of Set 15 | nuuk
# Processing Record 41 of Set 15 | sukhinichi
# Processing Record 42 of Set 15 | vardo
# Processing Record 43 of Set 15 | san patricio
# Processing Record 44 of Set 15 | zhezkazgan
# Processing Record 45 of Set 15 | bucak
# Processing Record 46 of Set 15 | yongan
# Processing Record 47 of Set 15 | tessalit
# Processing Record 48 of Set 15 | leh
# Processing Record 49 of Set 15 | bulgan
# Processing Record 50 of Set 15 | oranjestad
# Processing Record 1 of Set 16 | irpa irpa
# Processing Record 2 of Set 16 | ewa beach
# Processing Record 3 of Set 16 | vanavara
# Processing Record 4 of Set 16 | tvoroyri
# Processing Record 5 of Set 16 | moerai
# Processing Record 6 of Set 16 | havoysund
# Processing Record 7 of Set 16 | roma
# Processing Record 8 of Set 16 | harrisonburg
# Processing Record 9 of Set 16 | anshun
# Processing Record 10 of Set 16 | harper
# Processing Record 11 of Set 16 | garelochhead
# Processing Record 12 of Set 16 | taoudenni
# Processing Record 13 of Set 16 | grindavik
# Processing Record 14 of Set 16 | raudeberg
# Processing Record 15 of Set 16 | porto novo
# Processing Record 16 of Set 16 | tabukiniberu
# City not found. Skipping...
# Processing Record 17 of Set 16 | ibara
# Processing Record 18 of Set 16 | roebourne
# Processing Record 19 of Set 16 | toliary
# City not found. Skipping...
# Processing Record 20 of Set 16 | campbell river
# Processing Record 21 of Set 16 | washougal
# Processing Record 22 of Set 16 | abonnema
# Processing Record 23 of Set 16 | rudnogorsk
# Processing Record 24 of Set 16 | whitehorse
# Processing Record 25 of Set 16 | nyagan
# Processing Record 26 of Set 16 | gamba
# Processing Record 27 of Set 16 | grand gaube
# Processing Record 28 of Set 16 | gines
# Processing Record 29 of Set 16 | koutiala
# Processing Record 30 of Set 16 | yuanping
# Processing Record 31 of Set 16 | pampa
# Processing Record 32 of Set 16 | ocean springs
# Processing Record 33 of Set 16 | ihosy
# Processing Record 34 of Set 16 | berehove
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(cities)
# Out:
# 784

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Rikitea      PF -23.1203 -134.9692     73.26        77           0
# 1        Alofi      NU -19.0595 -169.9187     76.89        69           1
# 2  Yellowknife      CA  62.4560 -114.3525     66.72        42          20
# 3    Boundiali      CI   9.5217   -6.4869     68.68        96         100
# 4   Challapata      BO -18.9000  -66.7667     45.10        31           9
# 5    Kolyshley      RU  52.7005   44.5367     57.81        91         100
# 6        Vaini      TO -21.2000 -175.2000     77.16        83          20
# 7       Kawalu      ID  -7.3817  108.2082     77.95        75          94
# 8     Bengkulu      ID  -3.8004  102.2655     83.68        68          24
# 9    Busselton      AU -33.6500  115.3333     60.35        72          41
#
#    Wind Speed Current Description
# 0        5.70          light rain
# 1       13.80           clear sky
# 2       10.36          few clouds
# 3        6.38     overcast clouds
# 4        5.03           clear sky
# 5        7.16          light rain
# 6        8.05          few clouds
# 7        4.76     overcast clouds
# 8        3.98          few clouds
# 9       17.18    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
